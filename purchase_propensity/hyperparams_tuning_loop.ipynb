# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams
from matplotlib import rc
sns.set(style='whitegrid', palette='muted',font_scale=1.5)
rcParams['figure.figsize'] = 16,10
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import confusion_matrix

from funcs import train_model, plot_cm, plot_learn, data_split

# %%
import inspect

# %%
for f in [train_model, plot_cm, plot_learn, data_split]:
    print(inspect.signature(f))
# Out:
# (X, y, Xv, yv, lr=0.001, epochs=30, batch_size=32, patience=2, class_w=None)
# (model, data, labels, p=0.5)
# (history)
# (df, sizes=30000, set_index=True)

# %%
df = pd.read_csv('Data_preprocessed.csv')

# %%
X_train, y_train, X_valid, y_valid, X_test, y_test = data_split(df) #function has implemented reindexing set by argument set_index
# Out:
# Training data:  395401  rows returned.
# Training targets:  395401  rows returned.
# Validation data:  30000  rows returned.
# Validation targets:  30000  rows returned.
# Test data:  30000  rows returned.
# Test targets:  30000  rows returned.

# %%
lrs = [0.001, 0.003, 0.005]
batches = [32, 64, 128]

for i in lrs:
    for b in batches:
        print('\nTraining a model with lr = ',i, ' and batch_size = ',b)
        history, model = train_model(X_train, y_train, X_valid, y_valid, lr = i, batch_size = b, patience = 1)
        plot_learn(history)
        plot_cm(model, X_valid, y_valid)
# Out:
# Training a model with lr =  0.001  and batch_size =  32
# Epoch 1/30
# 12357/12357 - 7s - loss: 0.0248 - auc: 0.9955 - val_loss: 0.0204 - val_auc: 0.9975
# Epoch 2/30
# 12357/12357 - 7s - loss: 0.0209 - auc: 0.9962 - val_loss: 0.0203 - val_auc: 0.9968
# Epoch 3/30
# 12357/12357 - 15s - loss: 0.0207 - auc: 0.9964 - val_loss: 0.0201 - val_auc: 0.9973
# Epoch 4/30
# 12357/12357 - 11s - loss: 0.0206 - auc: 0.9964 - val_loss: 0.0203 - val_auc: 0.9977
# True Negatives:  28577
# False Positives:  190
# False Negatives:  18
# True Positives:  1215
# Total predicted purchases:  1405
# Model precision:  0.8647686832740213
# Model recall:  0.9854014598540146
# Model accuracy:  0.9930666666666667
#
# Training a model with lr =  0.001  and batch_size =  64
# Epoch 1/30
# 6179/6179 - 6s - loss: 0.0259 - auc: 0.9951 - val_loss: 0.0205 - val_auc: 0.9976
# Epoch 2/30
# 6179/6179 - 8s - loss: 0.0209 - auc: 0.9961 - val_loss: 0.0203 - val_auc: 0.9975
# Epoch 3/30
# ...
